# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('data.csv')
fig=plt.figure()
axes1=fig.add_subplot(1,1,1)
axes1.hist(df['International Reputation'],bins=50)
axes1.set_title('International Reputation')
fig
